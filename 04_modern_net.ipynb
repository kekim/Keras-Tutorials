# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import RMSprop
from keras.datasets import mnist
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128
nb_classes = 10
nb_epoch = 100

# %%
# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
# Deep Multilayer Perceptron model
model = Sequential()
model.add(Dense(input_dim=784, units=625, kernel_initializer="normal"))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(input_dim=625, units=625, kernel_initializer="normal"))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(input_dim=625, units=10, kernel_initializer="normal"))
model.add(Activation('softmax'))

model.compile(optimizer=RMSprop(lr=0.001, rho=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 625)               490625
# _________________________________________________________________
# activation_1 (Activation)    (None, 625)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 625)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 625)               391250
# _________________________________________________________________
# activation_2 (Activation)    (None, 625)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 625)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                6260
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 888,135
# Trainable params: 888,135
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train
history = model.fit(X_train, Y_train, epochs=nb_epoch, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.2624 - acc: 0.9196
# Epoch 2/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1124 - acc: 0.9666
# Epoch 3/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0816 - acc: 0.9754
# Epoch 4/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0686 - acc: 0.9802
# Epoch 5/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0584 - acc: 0.9825
# Epoch 6/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0500 - acc: 0.9853
# Epoch 7/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0465 - acc: 0.9870
# Epoch 8/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0421 - acc: 0.9890
# Epoch 9/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0391 - acc: 0.9892
# Epoch 10/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0349 - acc: 0.9903
# Epoch 11/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0344 - acc: 0.9912
# Epoch 12/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0326 - acc: 0.9918
# Epoch 13/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0329 - acc: 0.9919
# Epoch 14/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0303 - acc: 0.9927
# Epoch 15/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0300 - acc: 0.9926
# Epoch 16/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0282 - acc: 0.9928
# Epoch 17/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0277 - acc: 0.9933
# Epoch 18/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0305 - acc: 0.9933
# Epoch 19/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0271 - acc: 0.9937
# Epoch 20/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0302 - acc: 0.9937
# Epoch 21/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0267 - acc: 0.9941
# Epoch 22/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0283 - acc: 0.9940
# Epoch 23/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0265 - acc: 0.9943
# Epoch 24/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0266 - acc: 0.9945
# Epoch 25/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0231 - acc: 0.9948
# Epoch 26/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0255 - acc: 0.9946
# Epoch 27/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0240 - acc: 0.9950
# Epoch 28/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0236 - acc: 0.9950
# Epoch 29/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0263 - acc: 0.9950
# Epoch 30/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0246 - acc: 0.9951
# Epoch 31/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0255 - acc: 0.9949
# Epoch 32/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0227 - acc: 0.9955
# Epoch 33/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0252 - acc: 0.9951
# Epoch 34/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0243 - acc: 0.9954
# Epoch 35/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0258 - acc: 0.9955
# Epoch 36/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0246 - acc: 0.9957
# Epoch 37/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0272 - acc: 0.9953
# Epoch 38/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0223 - acc: 0.9956
# Epoch 39/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0