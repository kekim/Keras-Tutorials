# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras import initializers

weight_initializer = initializers.RandomNormal(stddev=0.01)

# %%
# Hyper parameters
batch_size = 128
nb_epoch = 50

# Parameters for MNIST dataset
img_rows, img_cols = 28, 28
nb_classes = 10

# Parameters for LSTM network
nb_lstm_outputs = 30
nb_time_steps = img_rows
dim_input_vector = img_cols

# %%
# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print('X_train original shape:', X_train.shape)
input_shape = (nb_time_steps, dim_input_vector)

X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train original shape: (60000, 28, 28)
# X_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples

# %%
# Build LSTM network
model = Sequential()
model.add(LSTM(nb_lstm_outputs, input_shape=input_shape))
model.add(Dense(nb_classes, activation='softmax', kernel_initializer=weight_initializer))
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 30)                7080
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                310
# =================================================================
# Total params: 7,390
# Trainable params: 7,390
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train
history = model.fit(X_train, Y_train, epochs=nb_epoch, batch_size=batch_size, shuffle=True, verbose=1)
# Out:
# Epoch 1/50
# 60000/60000 [==============================] - 14s 241us/step - loss: 1.3377 - acc: 0.5968
# Epoch 2/50
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.5727 - acc: 0.8345
# Epoch 3/50
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.3675 - acc: 0.8952
# Epoch 4/50
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2759 - acc: 0.9218
# Epoch 5/50
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2210 - acc: 0.9360
# Epoch 6/50
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.1867 - acc: 0.9463
# Epoch 7/50
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.1625 - acc: 0.9532
# Epoch 8/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.1436 - acc: 0.9577
# Epoch 9/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.1306 - acc: 0.9620
# Epoch 10/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.1202 - acc: 0.9655
# Epoch 11/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.1112 - acc: 0.9673
# Epoch 12/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.1032 - acc: 0.9699
# Epoch 13/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0971 - acc: 0.9717
# Epoch 14/50
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.0934 - acc: 0.9725
# Epoch 15/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0873 - acc: 0.9740
# Epoch 16/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0832 - acc: 0.9758
# Epoch 17/50
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.0775 - acc: 0.9773
# Epoch 18/50
# 60000/60000 [==============================] - 14s 241us/step - loss: 0.0745 - acc: 0.9781
# Epoch 19/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0710 - acc: 0.9792
# Epoch 20/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0683 - acc: 0.9798
# Epoch 21/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0653 - acc: 0.9804
# Epoch 22/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0632 - acc: 0.9814
# Epoch 23/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0603 - acc: 0.9820
# Epoch 24/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0584 - acc: 0.9834
# Epoch 25/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0557 - acc: 0.9834
# Epoch 26/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0535 - acc: 0.9839
# Epoch 27/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0513 - acc: 0.9846
# Epoch 28/50
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.0504 - acc: 0.9852
# Epoch 29/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0492 - acc: 0.9856
# Epoch 30/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0467 - acc: 0.9860
# Epoch 31/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0453 - acc: 0.9864
# Epoch 32/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0436 - acc: 0.9868
# Epoch 33/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0423 - acc: 0.9874
# Epoch 34/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0419 - acc: 0.9872
# Epoch 35/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0410 - acc: 0.9877
# Epoch 36/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0397 - acc: 0.9881
# Epoch 37/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0381 - acc: 0.9887
# Epoch 38/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0374 - acc: 0.9888
# Epoch 39/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0363 - acc: 0.9896
# Epoch 40/50
# 60000/60000 [==============================] - 14s 241us/step - loss: 0.0345 - acc: 0.9897
# Epoch 41/50
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.0343 - acc: 0.9893
# Epoch 42/50
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.0335 - acc: 0.9899
# Epoch 43/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0321 - acc: 0.9900
# Epoch 44/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0324 - acc: 0.9900
# Epoch 45/50
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.0309 - acc: 0.9906
# Epoch 46/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0290 - acc: 0.9911
# Epoch 47/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0292 - acc: 0.9912
# Epoch 48/50
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.0280 - acc: 0.9917
# Epoch 49/50
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.0278 - acc: 0.9913
# Epoch 50/50
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0270 - acc: 0.9914

# %%
# Evaluate
evaluation = model.evaluate(X_test, Y_test, batch_size=batch_size, verbose=1)
print('Summary: Loss over the test dataset: %.2f, Accuracy: %.2f' % (evaluation[0], evaluation[1]))
# Out:
# 10000/10000 [==============================] - 1s 91us/step
# Summary: Loss over the test dataset: 0.07, Accuracy: 0.98
